# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

import pandas as pd
from src.utils import Data
import matplotlib.pyplot as plt
import altair as alt
alt.renderers.enable('mimetype')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#      Zip      City State   Latitude  Longitude  Timezone  \
# 0  71937      Cove    AR  34.398483  -94.39398        -6
# 1  72044  Edgemont    AR  35.624351  -92.16056        -6
# 2  56171  Sherburn    MN  43.660847  -94.74357        -6
# 3  49430    Lamont    MI  43.010337  -85.89754        -5
# 4  52585  Richland    IA  41.194129  -91.98027        -6
#
#    Daylight savings time flag             geopoint
# 0                           1  34.398483,-94.39398
# 1                           1  35.624351,-92.16056
# 2                           1  43.660847,-94.74357
# 3                           1  43.010337,-85.89754
# 4                           1  41.194129,-91.98027

# %%
line = alt.Chart(df)\
    .mark_line(interpolate='basis')\
    .encode(
        x='date:T',
        y='daily_increase:Q',
        color='Admin2:N'
)
line

# %%
# Out:
# NumExpr defaulting to 4 threads.
#          Zip                     City State   Latitude  Longitude  Timezone  \
# 78     21634            Fishing Creek    MD  38.288409 -76.201460        -5
# 205    20868             Spencerville    MD  39.127028 -76.963720        -5
# 206    21849              Parsonsburg    MD  38.363057 -75.455740        -5
# 241    21241                Baltimore    MD  39.284707 -76.620489        -5
# 259    21767             Maugansville    MD  39.697894 -77.745140        -5
# ...      ...                      ...   ...        ...        ...       ...
# 42734  21555                  Oldtown    MD  39.579649 -78.558260        -5
# 42832  21005  Aberdeen Proving Ground    MD  39.473451 -76.140830        -5
# 42846  20875               Germantown    MD  39.143979 -77.207617        -5
# 43000  20623               Cheltenham    MD  38.748872 -76.830750        -5
# 43042  21155                  Upperco    MD  39.566103 -76.821250        -5
#
#        Daylight savings time flag              geopoint
# 78                              1   38.288409,-76.20146
# 205                             1   39.127028,-76.96372
# 206                             1   38.363057,-75.45574
# 241                             1  39.284707,-76.620489
# 259                             1   39.697894,-77.74514
# ...                           ...                   ...
# 42734                           1   39.579649,-78.55826
# 42832                           1   39.473451,-76.14083
# 42846                           1  39.143979,-77.207617
# 43000                           1   38.748872,-76.83075
# 43042                           1   39.566103,-76.82125
#
# [624 rows x 8 columns]
